# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('gps.csv')

# %%
df.columns
# Out:
# Index(['GameID', 'Half', 'PlayerID', 'FrameID', 'Time', 'GameClock', 'Speed',
#        'AccelImpulse', 'AccelLoad', 'AccelX', 'AccelY', 'AccelZ', 'Longitude',
#        'Latitude'],
#       dtype='object')

# %%
df = df[['GameID', 'PlayerID', 'FrameID', 'Speed','AccelImpulse', 'AccelLoad', 'AccelX', 'AccelY', 'AccelZ']]
df = df[df.PlayerID < 18]

# %%
df.head()
# Out:
#    GameID  PlayerID  FrameID     Speed  AccelImpulse  AccelLoad   AccelX  \
# 0       1         2        1  0.658334      0.611112   0.005330  0.13250
# 1       1         2        2  0.594445      0.638889   0.006568  0.11125
# 2       1         2        3  0.363889      2.305557   0.003114  0.01375
# 3       1         2        4  0.444445      0.805556   0.002602  0.00625
# 4       1         2        5  0.400000      0.444445   0.003813 -0.01750
#
#     AccelY   AccelZ
# 0  0.69875  0.56500
# 1  0.92000  0.70625
# 2  0.77000  0.67750
# 3  0.88625  0.59500
# 4  0.85750  0.57375

# %%
speed = df.groupby(['PlayerID', 'GameID'])['Speed'].mean()
speed = pd.DataFrame(data=speed).reset_index()
speed
# Out:
#      PlayerID  GameID     Speed
# 0           1      11  1.826543
# 1           1      12  1.334755
# 2           1      13  0.871128
# 3           1      14  0.894328
# 4           1      15  0.859702
# 5           1      16  0.815308
# 6           1      17  1.701283
# 7           1      18  1.228149
# 8           1      19  1.624167
# 9           1      20  1.353663
# 10          1      21  1.869350
# 11          1      22  1.672019
# 12          1      23  1.444136
# 13          1      24  1.624167
# 14          1      25  1.353663
# 15          1      26  1.869350
# 16          1      27  1.672019
# 17          1      28  1.444136
# 18          1      29  1.607029
# 19          1      30  1.204724
# 20          1      31  1.473693
# 21          1      32  1.493247
# 22          1      33  1.746016
# 23          1      34  1.571920
# 24          1      35  1.698299
# 25          1      36  1.752375
# 26          1      37  1.707616
# 27          1      38  1.514871
# 28          2       1  0.790156
# 29          2       2  1.744216
# ..        ...     ...       ...
# 413        16      14  0.840980
# 414        16      15  0.278610
# 415        16      16  0.904397
# 416        16      17  1.071021
# 417        16      18  1.154207
# 418        16      19  1.314597
# 419        16      20  0.971736
# 420        16      21  0.137209
# 421        16      22  1.942892
# 422        16      23  1.067613
# 423        16      24  1.314597
# 424        16      25  0.971736
# 425        16      26  0.137209
# 426        16      27  1.942892
# 427        16      28  1.067613
# 428        16      29  1.005246
# 429        16      30  0.436411
# 430        16      31  0.840285
# 431        16      32  1.072699
# 432        16      33  0.405876
# 433        16      35  1.555995
# 434        16      36  0.943302
# 435        16      37  0.826342
# 436        16      38  0.906961
# 437        17       1  0.397372
# 438        17       2  0.637043
# 439        17       3  0.741845
# 440        17       4  0.182575
# 441        17       5  0.010747
# 442        17       6  1.726543
#
# [443 rows x 3 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=df[df.PlayerID < 2]

# %%
speed = df.groupby(['PlayerID', 'GameID'])['Speed'].mean()
speed = pd.DataFrame(data=speed).reset_index()
speed
# Out:
#     PlayerID  GameID     Speed
# 0          1      11  1.826543
# 1          1      12  1.334755
# 2          1      13  0.871128
# 3          1      14  0.894328
# 4          1      15  0.859702
# 5          1      16  0.815308
# 6          1      17  1.701283
# 7          1      18  1.228149
# 8          1      19  1.624167
# 9          1      20  1.353663
# 10         1      21  1.869350
# 11         1      22  1.672019
# 12         1      23  1.444136
# 13         1      24  1.624167
# 14         1      25  1.353663
# 15         1      26  1.869350
# 16         1      27  1.672019
# 17         1      28  1.444136
# 18         1      29  1.607029
# 19         1      30  1.204724
# 20         1      31  1.473693
# 21         1      32  1.493247
# 22         1      33  1.746016
# 23         1      34  1.571920
# 24         1      35  1.698299
# 25         1      36  1.752375
# 26         1      37  1.707616
# 27         1      38  1.514871

# %%
AccelImpulse = df.groupby(['PlayerID', 'GameID'])['AccelImpulse'].mean()
AccelImpulse = pd.DataFrame(data=AccelImpulse).reset_index()
AccelImpulse
# Out:
#     PlayerID  GameID  AccelImpulse
# 0          1      11      1.466971
# 1          1      12      1.114262
# 2          1      13      0.932713
# 3          1      14      0.784174
# 4          1      15      0.753487
# 5          1      16      0.857045
# 6          1      17      1.324025
# 7          1      18      1.069903
# 8          1      19      1.345357
# 9          1      20      1.176307
# 10         1      21      1.349591
# 11         1      22      1.264157
# 12         1      23      1.252855
# 13         1      24      1.345357
# 14         1      25      1.176307
# 15         1      26      1.349591
# 16         1      27      1.264157
# 17         1      28      1.252855
# 18         1      29      1.288617
# 19         1      30      1.031755
# 20         1      31      1.254397
# 21         1      32      1.253575
# 22         1      33      1.362457
# 23         1      34      1.273526
# 24         1      35      1.234198
# 25         1      36      1.449142
# 26         1      37      1.313562
# 27         1      38      1.313265

# %%
AccelLoad = df.groupby(['PlayerID', 'GameID'])['AccelLoad'].mean()
AccelLoad = pd.DataFrame(data=AccelLoad).reset_index()
AccelLoad
# Out:
#     PlayerID  GameID  AccelLoad
# 0          1      11   0.029523
# 1          1      12   0.021369
# 2          1      13   0.015887
# 3          1      14   0.014801
# 4          1      15   0.013471
# 5          1      16   0.012908
# 6          1      17   0.028353
# 7          1      18   0.019309
# 8          1      19   0.027653
# 9          1      20   0.021668
# 10         1      21   0.029722
# 11         1      22   0.026092
# 12         1      23   0.025214
# 13         1      24   0.027653
# 14         1      25   0.021668
# 15         1      26   0.029722
# 16         1      27   0.026092
# 17         1      28   0.025214
# 18         1      29   0.024707
# 19         1      30   0.020308
# 20         1      31   0.023415
# 21         1      32   0.024752
# 22         1      33   0.027184
# 23         1      34   0.025338
# 24         1      35   0.022916
# 25         1      36   0.027529
# 26         1      37   0.024231
# 27         1      38   0.022910

# %%
plt.figure(figsize = (20,10))
ax = sns.barplot(x="GameID",y="Speed",hue="PlayerID",data=speed)

# %%
ax = sns.barplot(x="GameID",y="AccelImpulse",hue="PlayerID",data=AccelImpulse)

# %%
ax = sns.barplot(x="GameID",y="AccelLoad",hue="PlayerID",data=AccelLoad)

# %%
from sklearn import preprocessing

player_num = df['PlayerID'].unique()
for num in player_num:
    df.loc[df['PlayerID'] == num,'Speed']  = 100*preprocessing.normalize([df.loc[df['PlayerID'] == num]['Speed']])[0]
    df.loc[df['PlayerID'] == num,'AccelImpulse']  = 100*preprocessing.normalize([df.loc[df['PlayerID'] == num]['AccelImpulse']])[0]
    df.loc[df['PlayerID'] == num,'AccelLoad']  = 100*preprocessing.normalize([df.loc[df['PlayerID'] == num]['AccelLoad']])[0]

# %%
df['Performance'] = df['Speed'] + df['AccelImpulse'] + df['AccelLoad']

# %%
df.shape
# Out:
# (4570160, 15)

# %%
performance = df.groupby(['PlayerID', 'GameID'])['Performance'].mean()
performance  = pd.DataFrame(data=performance).reset_index()
performance.head()
# Out:
#    PlayerID  GameID  Performance
# 0         1      11     0.429158
# 1         1      12     0.317125
# 2         1      13     0.235842
# 3         1      14     0.218280
# 4         1      15     0.206759

# %%
performance.shape
# Out:
# (448, 3)

# %%
#design threshold
percent_first = np.percentile(performance['Performance'],33)
percent_second = np.percentile(performance['Performance'],67)
percent_first
# Out:
# 0.2517941962025617

# %%
#thresholding data
performance['catagory'] = 'low'
performance.loc[performance['Performance']>percent_first,'catagory'] = 'medium'
performance.loc[performance['Performance']>percent_second,'catagory'] = 'high'

# %%
performance
# Out:
#      PlayerID  GameID  Performance catagory
# 0           1      11     0.429158     high
# 1           1      12     0.317125   medium
# 2           1      13     0.235842      low
# 3           1      14     0.218280      low
# 4           1      15     0.206759      low
# 5           1      16     0.211238      low
# 6           1      17     0.398806     high
# 7           1      18     0.294962   medium
# 8           1      19     0.391428     high
# 9           1      20     0.326351   medium
# 10          1      21     0.421662     high
# 11          1      22     0.381030     high
# 12          1      23     0.356361     high
# 13          1      24     0.391428     high
# 14          1      25     0.326351   medium
# 15          1      26     0.421662     high
# 16          1      27     0.381030     high
# 17          1      28     0.356361     high
# 18          1      29     0.372290     high
# 19          1      30     0.292996   medium
# 20          1      31     0.351901   medium
# 21          1      32     0.358890     high
# 22          1      33     0.401990     high
# 23          1      34     0.370189     high
# 24          1      35     0.367532     high
# 25          1      36     0.412829     high
# 26          1      37     0.381767     high
# 27          1      38     0.359528     high
# 28          2       1     0.199354      low
# 29          2       2     0.402881     high
# ..        ...     ...          ...      ...
# 418        16      19     0.395802     high
# 419        16      20     0.311976   medium
# 420        16      21     0.074779      low
# 421        16      22     0.538426     high
# 422        16      23     0.324449   medium
# 423        16      24     0.395802     high
# 424        16      25     0.311976   medium
# 425        16      26     0.074779      low
# 426        16      27     0.538426     high
# 427        16      28     0.324449   medium
# 428        16      29     0.306189   medium
# 429        16      30     0.156195      low
# 430        16      31     0.263680   medium
# 431        16      32     0.330788   medium
# 432        16      33     0.134618      low
# 433        16      35     0.445111     high
# 434        16      36     0.296199   medium
# 435        16      37     0.250682      low
# 436        16      38     0.275654   medium
# 437        17       1     0.399742     high
# 438        17       2     0.610226     high
# 439        17       3     0.684335     high
# 440        17       4     0.212023      low
# 441        17       5     0.045552      low
# 442        17       6     1.583004     high
# 443        18       4     1.550534     high
# 444        19       4     1.371755     high
# 445        20       4     1.505136     high
# 446        21       4     1.481001     high
# 447        21       7     0.244968      low
#
# [448 rows x 4 columns]

# %%
plt.plot(df['Performance'])
